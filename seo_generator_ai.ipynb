# %% [markdown]
# <a href="https://colab.research.google.com/github/mizoamin/mizo-assets-core/blob/main/seo_generator_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Audio, display

print("🔊 جاري تشغيل 'نبض' للحفاظ على الاتصال...")
# هذا الكود ينشئ مشغل صوتي لمقطع صامت (Silence)
# الخاصية autoplay=True تعني التشغيل التلقائي
# لكن قد تحتاج للضغط على زر التشغيل يدوياً إذا منعه المتصفح
display(Audio(url='https://upload.wikimedia.org/wikipedia/commons/7/75/Silence_1_second.ogg', autoplay=True))

print("⚠️ ملاحظة هامة: تأكد من ضبط المشغل الصوتي على وضع التكرار (Loop) إن أمكن، ولا تغلق صفحة المتصفح.")
# Out:
# 🔊 جاري تشغيل 'نبض' للحفاظ على الاتصال...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="https://upload.wikimedia.org/wikipedia/commons/7/75/Silence_1_second.ogg" type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ⚠️ ملاحظة هامة: تأكد من ضبط المشغل الصوتي على وضع التكرار (Loop) إن أمكن، ولا تغلق صفحة المتصفح.

# %%
# @title 🕵️‍♂️ Mizo API Discovery Tool (كاشف الموديلات المتاحة)
import requests
import json

# مفتاحك
PAID_API_KEY = "AIzaSyCmZgn5DarHki7t8IACWi4kZqlMm1k1jTQ"

print("📡 جاري الاتصال بجوجل لجلب قائمة الموديلات المتاحة لحسابك...")

url = f"https://generativelanguage.googleapis.com/v1beta/models?key={PAID_API_KEY}"

try:
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        print("\n✅ تم الاتصال بنجاح! هذه هي الموديلات المسموحة لك:")
        print("="*50)
        valid_models = []
        for model in data.get('models', []):
            # نبحث فقط عن موديلات Gemini التي تقبل الصور
            if 'gemini' in model['name'] and 'vision' in str(model.get('supportedGenerationMethods', [])) or 'generateContent' in str(model.get('supportedGenerationMethods', [])):
                print(f"🔹 الاسم: {model['name']}")
                print(f"   الوصف: {model.get('description', 'No desc')}")
                valid_models.append(model['name'])
                print("-" * 30)

        print(f"\n💡 النصيحة: الموديل الذي سنختاره يجب أن يكون في هذه القائمة.")
    else:
        print(f"❌ خطأ في الاتصال: {response.status_code}")
        print(response.text)

except Exception as e:
    print(f"⚠️ خطأ فني: {e}")
# Out:
# 📡 جاري الاتصال بجوجل لجلب قائمة الموديلات المتاحة لحسابك...
#
# ✅ تم الاتصال بنجاح! هذه هي الموديلات المسموحة لك:
# ...
# 🔹 الاسم: models/gemini-2.5-flash
#    الوصف: Stable version of Gemini 2.5 Flash, our mid-size multimodal model that supports up to 1 million tokens, released in June of 2025.
# ------------------------------
# 🔹 الاسم: models/gemini-2.5-pro
#    الوصف: Stable release (June 17th, 2025) of Gemini 2.5 Pro
# ------------------------------
# 🔹 الاسم: models/gemini-2.0-flash-exp
#    الوصف: Gemini 2.0 Flash Experimental
# ------------------------------
# 🔹 الاسم: models/gemini-2.0-flash
#    الوصف: Gemini 2.0 Flash
# ------------------------------
# 🔹 الاسم: models/gemini-2.0-flash-001
#    الوصف: Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model for scaling across diverse tasks, released in January of 2025.
# ------------------------------
# 🔹 الاسم: models/gemini-2.0-flash-exp-image-generation
# ...

# %%
# @title 🏎️ Speed & Tier Test (Using gemini-flash-latest)
import time, requests
from concurrent.futures import ThreadPoolExecutor

# YOUR KEY
PAID_API_KEY = "AIzaSyCmZgn5DarHki7t8IACWi4kZqlMm1k1jTQ"
API_URL = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-flash-latest:generateContent?key={PAID_API_KEY}"

def quick_test(idx):
    try:
        payload = {"contents": [{"parts": [{"text": "Reply 'OK'"}]}]}
        start = time.time()
        res = requests.post(API_URL, json=payload, headers={"Content-Type": "application/json"})
        dur = time.time() - start
        if res.status_code == 200: return f"✅ Request {idx}: Success ({dur:.2f}s)"
        else: return f"❌ Request {idx}: Failed ({res.status_code})"
    except Exception as e: return f"⚠️ Error: {e}"

print("🚀 Starting Parallel Speed Test (20 requests at once)...")
start_time = time.time()

with ThreadPoolExecutor(max_workers=20) as executor:
    results = list(executor.map(quick_test, range(20)))

total_time = time.time() - start_time
print("\n".join(results))
print(f"\n⚡ Total Time: {total_time:.2f}s")
if total_time < 5:
    print("💎 Result: TIER 1 CONFIRMED (Super Fast!)")
else:
    print("🐢 Result: Slower than expected (Check Network)")
# Out:
# 🚀 Starting Parallel Speed Test (20 requests at once)...
# ✅ Request 0: Success (0.66s)
# ✅ Request 1: Success (0.61s)
# ✅ Request 2: Success (0.63s)
# ✅ Request 3: Success (0.62s)
# ✅ Request 4: Success (0.62s)
# ✅ Request 5: Success (0.63s)
# ✅ Request 6: Success (0.60s)
# ✅ Request 7: Success (0.61s)
# ✅ Request 8: Success (0.61s)
# ✅ Request 9: Success (0.59s)
# ✅ Request 10: Success (0.57s)
# ✅ Request 11: Success (0.61s)
# ✅ Request 12: Success (0.51s)
# ✅ Request 13: Success (0.66s)
# ✅ Request 14: Success (0.60s)
# ✅ Request 15: Success (0.59s)
# ✅ Request 16: Success (0.60s)
# ✅ Request 17: Success (0.60s)
# ✅ Request 18: Success (0.59s)
# ✅ Request 19: Success (0.57s)
#
# ⚡ Total Time: 0.71s
# 💎 Result: TIER 1 CONFIRMED (Super Fast!)

# %%
# @title 👑 Mizo Amin: THE IMPERIAL MONITOR V21 (Family Recognition + Turbo Dashboard)
# ------------------------------------------------------------------
# ✅ الميزة الكبرى: "مصفوفة العائلة" للتعرف على (Jude, Layla, Nada, Parents...)
# ✅ السرعة: 10 Threads (Turbo Speed with Stability)
# ✅ العرض: شاشة مراقبة سينمائية تعرض كل الحقول والروابط
# ✅ الملفات: V8 JSON, V8 TXT, V20 AI Report, Master List, Backups
# ------------------------------------------------------------------

import os, json, time, base64, requests, glob, datetime, shutil
from concurrent.futures import ThreadPoolExecutor, as_completed
from google.colab import drive
from IPython.display import clear_output
from PIL import Image
import io

# 🔑 مفتاحك (Tier 1 Confirmed)
PAID_API_KEY = "AIzaSyCmZgn5DarHki7t8IACWi4kZqlMm1k1jTQ"

# 🛠️ التجهيز
try:
    from pillow_heif import register_heif_opener
    register_heif_opener()
except:
    import subprocess
    print("⚙️ Installing Libraries...")
    subprocess.check_call(["pip", "install", "pillow-heif"])
    from pillow_heif import register_heif_opener
    register_heif_opener()

print("📂 Connecting to Drive...")
drive.mount('/content/drive')

# 🔥 الرابط الرسمي المستقر (الأسرع والأذكى)
API_URL = f"https://generativelanguage.googleapis.com/v1beta/models/gemini-flash-latest:generateContent?key={PAID_API_KEY}"

BASE_PATH = "/content/drive/MyDrive/mizo_production_assets"
FACES_PATH = f"{BASE_PATH}/reference_faces"

# 💾 نظام الملفات الكامل (كما طلبت)
OUTPUT_JSON = f"{BASE_PATH}/assets_manifest_v8.json"
OUTPUT_TXT = f"{BASE_PATH}/seo-v8.txt"
MASTER_LIST = f"{BASE_PATH}/master_image_list_v8.txt"
FUTURE_PROMPT_FILE = f"{BASE_PATH}/seo_ai_readable_report_V20.txt"
FOLDER_MAP = f"{BASE_PATH}/folder_structure_plan.txt"
BACKUP_DIR = f"{BASE_PATH}/json_backups_v8"

if not os.path.exists(BACKUP_DIR):
    os.makedirs(BACKUP_DIR)

# تحميل الوجوه المرجعية
reference_names = []
if os.path.exists(FACES_PATH):
    face_files = os.listdir(FACES_PATH)
    reference_names = [os.path.splitext(f)[0] for f in face_files if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    print(f"👤 Loaded {len(reference_names)} reference faces.")

# 📜 سياق القصة (Bio) - لذكاء السياق
MIZO_BIO_CONTEXT = """
SUBJECT: Mizo Amin (Mohamed Hassan Abdelmoaty Mohamed).
BORN: Aug 3, 1991 (Giza, Egypt). Lived in Doha, Qatar for 34 years.
ROLE: Professional Basketball Player, Team Captain (Al Shamal SC), Ex-Captain (Al Rayyan & Qatar National Team).
CAREER: Youngest player to join Qatar National Team. Best 3-Point Shooter in Gulf (2017).
BUSINESS: Founder of 'Punchy Store'. IT Expert & Marketer.
PHILOSOPHY: "A Leader is a Reader" & "Nothing can Substitute Experience".
"""

# 👨‍👩‍👧‍👦 مصفوفة العائلة (Family Matrix) - لذكاء التعرف على الأشخاص
FAMILY_CONTEXT = """
CORE FAMILY IDENTITIES (LOOK FOR THESE FACES & TAG THEM):
1. **Mizo Amin**: Main subject. Tall, athletic basketball player.
2. **Nada Deraz**: Wife. Female adult.
3. **Jude**: Eldest daughter (young girl).
4. **Layla**: Younger daughter (little girl).
5. **Hassan & Fareed**: Twin young boys (sons).
6. **Hassan Amin**: Father. Older man, former Captain/Coach.
7. **Lubna**: Mother. Older woman.
8. **Friends**: Look for teammates in basketball jerseys (Al Shamal / Qatar Team).
"""

# أسماء ميزو الكاملة (تضاف تلقائياً)
MIZO_FULL_NAMES = [
    "Mizo Amin", "Mohamed Hassan Abdelmoaty Mohamed", "Mohamed Hassan A Mohamed",
    "ميزو أمين", "محمد حسن عبد المعطي محمد", "محمد حسن عبد المعطي محمد أمين"
]

# ------------------------------------------------------------------
# 1. Map Generator
# ------------------------------------------------------------------
def generate_content_map(base_path):
    if not os.path.exists(FOLDER_MAP):
        with open(FOLDER_MAP, 'w', encoding='utf-8') as f:
            f.write("MIZO AMIN ARCHIVE MAP\n=====================\n")
            for root, dirs, files in os.walk(base_path):
                folder = os.path.basename(root)
                if not folder.startswith('.'):
                    f.write(f"[DIR] {folder}/ ({len(files)} files)\n")

# ------------------------------------------------------------------
# 2. Engine (V21 Imperial)
# ------------------------------------------------------------------
def process_imperial_engine(image_path):
    filename = os.path.basename(image_path)
    folder_name = os.path.basename(os.path.dirname(image_path))

    try:
        with Image.open(image_path) as img:
            if img.mode != 'RGB': img = img.convert('RGB')
            # ضغط ذكي 1024 لضمان السرعة والجودة معاً
            img.thumbnail((1024, 1024))
            buffer = io.BytesIO()
            img.save(buffer, format="JPEG", quality=85)
            image_data = base64.b64encode(buffer.getvalue()).decode("utf-8")
    except Exception as e:
        return {"status": "error", "file": filename, "msg": f"Image Error: {str(e)}"}

    # البرومبت الشامل (القصة + العائلة + الصحافة)
    prompt_text = f"""
    ROLE: Elite Sports Journalist, Photographer & Creative Director for Mizo Amin.

    BIO CONTEXT: {MIZO_BIO_CONTEXT}
    FAMILY CONTEXT: {FAMILY_CONTEXT}

    TASK: Analyze image '{filename}' from folder: '{folder_name}'.

    GUIDELINES:
    1. **Style**: Inspiring, High-energy, Legendary. Use action verbs.
    2. **Family ID**: Use the FAMILY CONTEXT to identify people (Jude, Layla, Nada, Hassan, Fareed...).
    3. **Context**: Use folder name for Year/City.
    4. **Language**: All fields English, EXCEPT 'Extra_Arabic_Caption' in Arabic.

    OUTPUT JSON (Strictly 18 Fields):
    {{
        "Title": "Creative Headline",
        "Caption": "Engaging Caption with emojis",
        "Description": "Detailed visual storytelling",
        "Meta_Description": "SEO hook",
        "Alt_Text": "Accessibility text",
        "Alt_Description": "Detailed accessibility description",
        "Year": "YYYY",
        "Location": "Place",
        "City": "City",
        "Country": "Country",
        "GEO_Tag": "Lat, Long",
        "SEO_Tags": ["Tag1", "Tag2"],
        "Google_Search_Tags": ["Query1", "Query2"],
        "Google_Images_Tags": ["VisualTag1"],
        "Keywords": ["Kw1", "Kw2"],
        "Tags": ["Cat1"],
        "Face_Tags": ["List ALL identified people here"],
        "Visual_Summary": "Summary",
        "Extra_Arabic_Caption": "كابشن عربي إبداعي وحماسي جداً",
        "Social_Links": {{
            "Wiki": "https://en.wikipedia.org/wiki/Mizo_Amin",
            "Knowledge": "g.co/kgs/VDbLGD",
            "Instagram": "https://www.instagram.com/mizoamin",
            "Facebook": "https://www.facebook.com/24mizoamin"
        }}
    }}
    """

    payload = {
        "contents": [{"parts": [{"text": prompt_text}, {"inline_data": {"mime_type": "image/jpeg", "data": image_data}}]}],
        "generationConfig": {"temperature": 1.0, "response_mime_type": "application/json"}
    }

    # محاولة سريعة (10 Threads)
    for attempt in range(3):
        try:
            response = requests.post(API_URL, json=payload, headers={"Content-Type": "application/json"}, timeout=60)

            if response.status_code == 200:
                data = json.loads(response.json()['candidates'][0]['content']['parts'][0]['text'])

                # المنطق الذكي للأسماء والروابط
                detected = str(data.get('Face_Tags', [])).lower()
                is_mizo = any(x in detected for x in ['mizo', 'amin', 'mezo'])

                if is_mizo:
                    existing = data.get('Face_Tags', [])
                    if isinstance(existing, list):
                        data['Face_Tags'] = list(set(existing + MIZO_FULL_NAMES))
                    else:
                        data['Face_Tags'] = MIZO_FULL_NAMES

                    if isinstance(data.get("Social_Links"), str):
                        data["Social_Links"] = {
                            "Wiki": "https://en.wikipedia.org/wiki/Mizo_Amin",
                            "Knowledge": "g.co/kgs/VDbLGD",
                            "Instagram": "https://www.instagram.com/mizoamin",
                            "Facebook": "https://www.facebook.com/24mizoamin"
                        }
                else:
                    data["Social_Links"] = "Hidden (Target Not Detected)"

                return {"status": "success", "file": filename, "path": image_path, "data": data}

            elif response.status_code == 429:
                time.sleep(2)
            else:
                time.sleep(1)
        except:
            time.sleep(1)

    return {"status": "error", "file": filename, "msg": "Timeout"}

# ------------------------------------------------------------------
# 3. الحفظ (The Archivist)
# ------------------------------------------------------------------
def save_all_reports(data_dict, counter):
    # V8 JSON
    with open(OUTPUT_JSON, 'w', encoding='utf-8') as f:
        json.dump(data_dict, f, ensure_ascii=False, indent=4)

    # V8 TXT
    with open(OUTPUT_TXT, 'w', encoding='utf-8') as f_txt:
        for fname, info in data_dict.items():
            d = info['data']
            f_txt.write(f"IMG: {fname}\nTITLE: {d.get('Title')}\nARABIC: {d.get('Extra_Arabic_Caption')}\nTAGS: {d.get('Face_Tags')}\n{'-'*40}\n")

    # V20 Future Report
    with open(FUTURE_PROMPT_FILE, 'w', encoding='utf-8') as f_future:
        f_future.write("MIZO AMIN ARCHIVE\n=================\n")
        for fname, info in data_dict.items():
            d = info['data']
            entry = f"[ID]: {fname}\n[VIS]: {d.get('Description')}\n[HDL]: {d.get('Title')}\n[TAGS]: {d.get('Face_Tags')}\n{'-'*30}\n"
            f_future.write(entry)

    # Master List
    with open(MASTER_LIST, 'w', encoding='utf-8') as f_master:
        for fname, info in data_dict.items():
            f_master.write(f"{info['path']}\n")

    # Backup
    if counter % 50 == 0:
        ts = datetime.datetime.now().strftime("%H%M%S")
        shutil.copy(OUTPUT_JSON, f"{BACKUP_DIR}/backup_v8_{ts}_{counter}.json")

def draw_colored_bar(percent, length=20):
    filled = int(length * percent // 100)
    return f"\033[92m{'█' * filled}\033[0m" + '░' * (length - filled)

# --- التنفيذ ---
all_images = []
generate_content_map(BASE_PATH)

print("🕵️‍♂️ Scanning Archive...")
for ext in ['**/*.webp', '**/*.jpg', '**/*.jpeg', '**/*.png', '**/*.HEIC', '**/*.heic']:
    all_images.extend(glob.glob(os.path.join(BASE_PATH, ext), recursive=True))

processed_data = {}
if os.path.exists(OUTPUT_JSON):
    with open(OUTPUT_JSON, 'r', encoding='utf-8') as f: processed_data = json.load(f)

queue = [img for img in all_images if os.path.basename(img) not in processed_data]
total_queue = len(queue)
start_time = time.time()

if queue:
    print(f"🚀 Found {total_queue} images. Starting V21 (Family + Turbo)...")

    # ⚡ 10 Threads = سرعة + استقرار
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = {executor.submit(process_imperial_engine, img): img for img in queue}
        completed_count = 0

        for count, future in enumerate(as_completed(futures)):
            res = future.result()
            completed_count += 1

            clear_output(wait=True)
            elapsed = time.time() - start_time
            rem_str = str(datetime.timedelta(seconds=int((total_queue - completed_count) * (elapsed / completed_count))))
            percent = (completed_count / total_queue) * 100

            # 💎 شاشة المراقبة الكاملة (THE IMPERIAL DASHBOARD) 💎
            print(f"{'='*30} 💎 IMPERIAL MONITOR V21 {'='*30}")
            print(f"📊 Progress: [{draw_colored_bar(percent)}] {percent:.2f}% ({completed_count}/{total_queue})")
            print(f"⏳ Time Left: {rem_str}")
            print("=" * 80)

            if res['status'] == 'success':
                d = res['data']
                print(f"📸 FILE: {res['file']}")
                print(f"--------------------------------------------------")
                print(f"• Title:              \033[1m{d.get('Title')}\033[0m")
                print(f"• Caption:            \033[96m{d.get('Caption')}\033[0m")
                print(f"• Arabic:             \033[92m{d.get('Extra_Arabic_Caption')}\033[0m")
                print(f"• Description:        {d.get('Description')[:150]}...")
                print(f"• Meta Desc:          {d.get('Meta_Description')}")
                print(f"• Alt Text:           {d.get('Alt_Text')}")
                print(f"• Alt Desc:           {d.get('Alt_Description')}")
                print(f"• Year:               {d.get('Year')}")
                print(f"• Location:           {d.get('Location')}")
                print(f"• Country:            {d.get('Country')}")
                print(f"• GEO Tag:            {d.get('GEO_Tag')}")
                print(f"• SEO Tags:           {d.get('SEO_Tags')}")
                print(f"• G-Search Tags:      {d.get('Google_Search_Tags')}")
                print(f"• G-Image Tags:       {d.get('Google_Images_Tags')}")
                print(f"• Keywords:           {d.get('Keywords')}")
                print(f"• Tags:               {d.get('Tags')}")
                # 🟡 أسماء العائلة هنا 🟡
                print(f"• Face Tags:          \033[93m{d.get('Face_Tags')}\033[0m")
                print(f"• Visual Summary:     {d.get('Visual_Summary')}")
                print(f"• City:               {d.get('City')}")

                social = d.get('Social_Links')
                if isinstance(social, dict):
                    print(f"• Social Links:       ✅ ACTIVE")
                    print(json.dumps(social, indent=4, ensure_ascii=False))
                else:
                    print(f"• Social Links:       ⚪ HIDDEN")

                print("=" * 80)

                processed_data[res['file']] = {"path": res['path'], "data": res['data']}
            else:
                print(f"⚠️ ERROR: {res['msg']}")

            if count % 50 == 0:
                save_all_reports(processed_data, completed_count)

    save_all_reports(processed_data, completed_count)
    print("\n🎉 تمت المهمة!")
else:
    print("✅ الأرشيف محدث.")
